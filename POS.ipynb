# %%
import spacy

# %%
nlp=spacy.load("en_core_web_sm")

# %%
doc=nlp("Elon flew to mars yesterday. He carried briyani masala with him")

# %%
for token in doc:
    print(token," | ",token.pos_," | ",spacy.explain(token.pos_))
# Out:
# Elon  |  PROPN  |  proper noun
# flew  |  VERB  |  verb
# to  |  ADP  |  adposition
# mars  |  NOUN  |  noun
# yesterday  |  NOUN  |  noun
# .  |  PUNCT  |  punctuation
# He  |  PRON  |  pronoun
# carried  |  VERB  |  verb
# briyani  |  ADJ  |  adjective
# masala  |  NOUN  |  noun
# with  |  ADP  |  adposition
# him  |  PRON  |  pronoun

# %%
doc=nlp("Wow! Dr.Strange made 265 million $ on the very first day")

# %%
for token in doc:
    print(token," | ",token.pos_," | ",spacy.explain(token.pos_)," | ",token.tag_, " | ",spacy.explain(token.tag_))
# Out:
# Wow  |  INTJ  |  interjection  |  UH  |  interjection
# !  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# Dr.  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Strange  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# made  |  VERB  |  verb  |  VBD  |  verb, past tense
# 265  |  NUM  |  numeral  |  CD  |  cardinal number
# million  |  NUM  |  numeral  |  CD  |  cardinal number
# $  |  NUM  |  numeral  |  CD  |  cardinal number
# on  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# very  |  ADV  |  adverb  |  RB  |  adverb
# first  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# day  |  NOUN  |  noun  |  NN  |  noun, singular or mass

# %%
doc=nlp("He quits the job")
token=doc[1]
print(doc[1].text , " | ",token.tag_, " | ",spacy.explain(token.tag_))
# Out:
# quits  |  VBZ  |  verb, 3rd person singular present

# %%
doc=nlp("He quit the job")
token=doc[1]
print(doc[1].text , " | ",token.tag_, " | ",spacy.explain(token.tag_))
# Out:
# quit  |  VBD  |  verb, past tense

# %%
doc=nlp("""Hitler was born in Braunau am Inn in Austria-Hungary and was raised near Linz. He lived in Vienna in the first decade of the 1900s before moving to Germany in 1913. He was decorated during his service in the German Army in World War I, receiving the Iron Cross. In 1919, he joined the German Workers' Party (DAP), the precursor of the Nazi Party, and in 1921 was appointed leader of the Nazi Party. In 1923, he attempted to seize governmental power in a failed coup in Munich and was sentenced to five years in prison, serving just over a year of his sentence. While there, he dictated the first volume of his autobiography and political manifesto Mein Kampf (My Struggle). After his early release in 1924, Hitler gained popular support by attacking the Treaty of Versailles and promoting pan-Germanism, antisemitism, and anti-communism with charismatic oratory and Nazi propaganda. He frequently denounced communism as being part of an international Jewish conspiracy.""")

# %%
for token in doc:
    if token.pos_ not in ["SPACE","X","PUNCT"]:
        print(token," | ",token.pos_," | ",spacy.explain(token.pos_)," | ",token.tag_, " | ",spacy.explain(token.tag_))
# Out:
# Hitler  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# was  |  AUX  |  auxiliary  |  VBD  |  verb, past tense
# born  |  VERB  |  verb  |  VBN  |  verb, past participle
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# Braunau  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# am  |  AUX  |  auxiliary  |  VBP  |  verb, non-3rd person singular present
# Inn  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# Austria  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Hungary  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# was  |  AUX  |  auxiliary  |  VBD  |  verb, past tense
# raised  |  VERB  |  verb  |  VBN  |  verb, past participle
# near  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# Linz  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# He  |  PRON  |  pronoun  |  PRP  |  pronoun, personal
# lived  |  VERB  |  verb  |  VBD  |  verb, past tense
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# Vienna  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# first  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# decade  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# 1900s  |  NOUN  |  noun  |  NNS  |  noun, plural
# before  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# moving  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# to  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# Germany  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# 1913  |  NUM  |  numeral  |  CD  |  cardinal number
# He  |  PRON  |  pronoun  |  PRP  |  pronoun, personal
# was  |  AUX  |  auxiliary  |  VBD  |  verb, past tense
# decorated  |  VERB  |  verb  |  VBN  |  verb, past participle
# during  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# his  |  PRON  |  pronoun  |  PRP$  |  pronoun, possessive
# service  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# German  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# Army  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# World  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# War  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# I  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# receiving  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# the  |  DET  |  determiner  |  DT  |  determiner
# Iron  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Cross  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# In  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# 1919  |  NUM  |  numeral  |  CD  |  cardinal number
# he  |  PRON  |  pronoun  |  PRP  |  pronoun, personal
# joined  |  VERB  |  verb  |  VBD  |  verb, past tense
# the  |  DET  |  determiner  |  DT  |  determiner
# German  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Workers  |  PROPN  |  proper noun  |  NNPS  |  noun, proper plural
# '  |  PART  |  particle  |  POS  |  possessive ending
# Party  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# DAP  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# the  |  DET  |  determiner  |  DT  |  determiner
# precursor  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# Nazi  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Party  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# 1921  |  NUM  |  numeral  |  CD  |  cardinal number
# was  |  AUX  |  auxiliary  |  VBD  |  verb, past tense
# appointed  |  VERB  |  verb  |  VBN  |  verb, past participle
# leader  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# Nazi  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Party  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# In  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# 1923  |  NUM  |  numeral  |  CD  |  cardinal number
# he  |  PRON  |  pronoun  |  PRP  |  pronoun, personal
# attempted  |  VERB  |  verb  |  VBD  |  verb, past tense
# to  |  PART  |  particle  |  TO  |  infinitival "to"
# seize  |  VERB  |  verb  |  VB  |  verb, base form
# governmental  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# power  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# a  |  DET  |  determiner  |  DT  |  determiner
# failed  |  VERB  |  verb  |  VBN  |  verb, past participle
# coup  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# Munich  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# was  |  AUX  |  auxiliary  |  VBD  |  verb, past tense
# sentenced  |  VERB  |  verb  |  VBN  |  verb, past participle
# to  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# five  |  NUM  |  numeral  |  CD  |  cardinal number
# years  |  NOUN  |  noun  |  NNS  |  noun, plural
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# prison  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# serving  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# just  |  ADV  |  adverb  |  RB  |  adverb
# over  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# a  |  PRON  |  pronoun  |  DT  |  determiner
# year  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# his  |  PRON  |  pronoun  |  PRP$  |  pronoun, possessive
# sentence  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# While  |  SCONJ  |  subordinating conjunction  |  IN  |  conjunction, subordinating or preposition
# there  |  PRON  |  pronoun  |  EX  |  existential there
# he  |  PRON  |  pronoun  |  PRP  |  pronoun, personal
# dictated  |  VERB  |  verb  |  VBD  |  verb, past tense
# the  |  DET  |  determiner  |  DT  |  determiner
# first  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# volume  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# his  |  PRON  |  pronoun  |  PRP$  |  pronoun, possessive
# autobiography  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# political  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# manifesto  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# Mein  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Kampf  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# My  |  PRON  |  pronoun  |  PRP$  |  pronoun, possessive
# Struggle  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# After  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# his  |  PRON  |  pronoun  |  PRP$  |  pronoun, possessive
# early  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# release  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# 1924  |  NUM  |  numeral  |  CD  |  cardinal number
# Hitler  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# gained  |  VERB  |  verb  |  VBD  |  verb, past tense
# popular  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# support  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# by  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# attacking  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# the  |  DET  |  determiner  |  DT  |  determiner
# Treaty  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# Versailles  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# promoting  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# pan  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# -  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Germanism  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# antisemitism  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# anti  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# -  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# communism  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# with  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# charismatic  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# oratory  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# Nazi  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# propaganda  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# He  |  PRON  |  pronoun  |  PRP  |  pronoun, personal
# frequently  |  ADV  |  adverb  |  RB  |  adverb
# denounced  |  VERB  |  verb  |  VBD  |  verb, past tense
# communism  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# as  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# being  |  AUX  |  auxiliary  |  VBG  |  verb, gerund or present participle
# part  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# an  |  DET  |  determiner  |  DT  |  determiner
# international  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# Jewish  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# conspiracy  |  NOUN  |  noun  |  NN  |  noun, singular or mass

# %%
for token in doc:
    if token.pos_ in ["SPACE","X","PUNCT"]:
        print(token," | ",token.pos_," | ",spacy.explain(token.pos_)," | ",token.tag_, " | ",spacy.explain(token.tag_))
# Out:
# -  |  PUNCT  |  punctuation  |  HYPH  |  punctuation mark, hyphen
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# (  |  PUNCT  |  punctuation  |  -LRB-  |  left round bracket
# )  |  PUNCT  |  punctuation  |  -RRB-  |  right round bracket
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# (  |  PUNCT  |  punctuation  |  -LRB-  |  left round bracket
# )  |  PUNCT  |  punctuation  |  -RRB-  |  right round bracket
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer

# %%
count=doc.count_by(spacy.attrs.POS)
count
# Out:
# {96: 31,
#  87: 7,
#  100: 18,
#  85: 31,
#  97: 23,
#  89: 7,
#  95: 13,
#  90: 12,
#  84: 12,
#  92: 25,
#  93: 6,
#  94: 2,
#  86: 2,
#  98: 1}

# %%
doc.vocab[96].text
# Out:
# 'PROPN'

# %%
for k, v in count.items():
    print(doc.vocab[k].text,v)
# Out:
# PROPN 31
# AUX 7
# VERB 18
# ADP 31
# PUNCT 23
# CCONJ 7
# PRON 13
# DET 12
# ADJ 12
# NOUN 25
# NUM 6
# PART 2
# ADV 2
# SCONJ 1

# %%
doc=nlp("""Inflation rose again in April, continuing a climb that has pushed consumers to the brink and is threatening the economic expansion, the Bureau of Labor Statistics reported Wednesday.

The consumer price index, a broad-based measure of prices for goods and services, increased 8.3% from a year ago, higher than the Dow Jones estimate for an 8.1% gain. That represented a slight ease from March’s peak but was still close to the highest level since the summer of 1982.

Removing volatile food and energy prices, so-called core CPI still rose 6.2%, against expectations for a 6% gain, clouding hopes that inflation had peaked in March.

The month-over-month gains also were higher than expectations — 0.3% on headline CPI versus the 0.2% estimate and a 0.6% increase for core, against the outlook for a 0.4% gain.

The price gains also meant that workers continued to lose ground. Real wages adjusted for inflation decreased 0.1% on the month despite a nominal increase of 0.3% in average hourly earnings. Over the past year, real earnings have dropped 2.6% even though average hourly earnings are up 5.5%.

Inflation has been the single biggest threat to a recovery that began early in the Covid pandemic and saw the economy in 2021 stage its biggest single-year growth level since 1984. Rising prices at the pump and in grocery stores have been one problem, but inflation has spread beyond those two areas into housing, auto sales and a host of other areas.

Federal Reserve officials have responded to the problem with two interest rate hikes so far this year and pledges of more until inflation comes down to the central bank’s 2% goal. However, Wednesday’s data shows that the Fed has a big job ahead.

Credits: cnbc.com""")

# %%
count=doc.count_by(spacy.attrs.POS)
count
# Out:
# {92: 96,
#  100: 27,
#  86: 15,
#  85: 39,
#  96: 16,
#  97: 32,
#  90: 34,
#  95: 4,
#  87: 13,
#  89: 10,
#  84: 23,
#  103: 7,
#  93: 19,
#  94: 4,
#  98: 8,
#  101: 1}

# %%
for k , v in count.items():
    print(doc.vocab[k].text , v)
# Out:
# NOUN 96
# VERB 27
# ADV 15
# ADP 39
# PROPN 16
# PUNCT 32
# DET 34
# PRON 4
# AUX 13
# CCONJ 10
# ADJ 23
# SPACE 7
# NUM 19
# PART 4
# SCONJ 8
# X 1

# %%
for token in doc:
    print(token.pos_)
# Out:
# NOUN
# VERB
# ADV
# ADP
# PROPN
# PUNCT
# VERB
# DET
# NOUN
# PRON
# AUX
# VERB
# NOUN
# ADP
# DET
# NOUN
# CCONJ
# AUX
# VERB
# DET
# ADJ
# NOUN
# PUNCT
# DET
# PROPN
# ADP
# PROPN
# PROPN
# VERB
# PROPN
# PUNCT
# SPACE
# DET
# NOUN
# NOUN
# NOUN
# PUNCT
# DET
# ADV
# PUNCT
# VERB
# NOUN
# ADP
# NOUN
# ADP
# NOUN
# CCONJ
# NOUN
# PUNCT
# VERB
# NUM
# NOUN
# ADP
# DET
# NOUN
# ADV
# PUNCT
# ADJ
# ADP
# DET
# PROPN
# PROPN
# NOUN
# ADP
# DET
# NUM
# NOUN
# NOUN
# PUNCT
# PRON
# VERB
# DET
# ADJ
# NOUN
# ADP
# PROPN
# PART
# NOUN
# CCONJ
# AUX
# ADV
# ADJ
# ADP
# DET
# ADJ
# NOUN
# SCONJ
# DET
# NOUN
# ADP
# NUM
# PUNCT
# SPACE
# VERB
# ADJ
# NOUN
# CCONJ
# NOUN
# NOUN
# PUNCT
# ADV
# PUNCT
# VERB
# NOUN
# PROPN
# ADV
# VERB
# NUM
# NOUN
# PUNCT
# ADP
# NOUN
# ADP
# DET
# NUM
# NOUN
# NOUN
# PUNCT
# VERB
# NOUN
# SCONJ
# NOUN
# AUX
# VERB
# ADP
# PROPN
# PUNCT
# SPACE
# DET
# NOUN
# PUNCT
# ADP
# PUNCT
# NOUN
# NOUN
# ADV
# AUX
# ADJ
# ADP
# NOUN
# PUNCT
# NUM
# NOUN
# ADP
# NOUN
# PROPN
# ADP
# DET
# NUM
# NOUN
# NOUN
# CCONJ
# DET
# NUM
# NOUN
# NOUN
# ADP
# NOUN
# PUNCT
# ADP
# DET
# NOUN
# ADP
# DET
# NUM
# NOUN
# NOUN
# PUNCT
# SPACE
# DET
# NOUN
# NOUN
# ADV
# VERB
# SCONJ
# NOUN
# VERB
# PART
# VERB
# NOUN
# PUNCT
# ADJ
# NOUN
# VERB
# ADP
# NOUN
# VERB
# NUM
# NOUN
# ADP
# DET
# NOUN
# SCONJ
# DET
# ADJ
# NOUN
# ADP
# NUM
# NOUN
# ADP
# ADJ
# ADJ
# NOUN
# PUNCT
# ADP
# DET
# ADJ
# NOUN
# PUNCT
# ADJ
# NOUN
# AUX
# VERB
# NUM
# NOUN
# ADV
# SCONJ
# ADJ
# ADJ
# NOUN
# AUX
# ADV
# NUM
# NOUN
# PUNCT
# SPACE
# NOUN
# AUX
# AUX
# DET
# ADJ
# ADJ
# NOUN
# ADP
# DET
# NOUN
# PRON
# VERB
# ADV
# ADP
# DET
# PROPN
# NOUN
# CCONJ
# VERB
# DET
# NOUN
# ADP
# NUM
# NOUN
# PRON
# ADJ
# ADJ
# PUNCT
# NOUN
# NOUN
# NOUN
# SCONJ
# NUM
# PUNCT
# VERB
# NOUN
# ADP
# DET
# NOUN
# CCONJ
# ADP
# NOUN
# NOUN
# AUX
# AUX
# NUM
# NOUN
# PUNCT
# CCONJ
# NOUN
# AUX
# VERB
# ADP
# DET
# NUM
# NOUN
# ADP
# NOUN
# PUNCT
# NOUN
# NOUN
# CCONJ
# DET
# NOUN
# ADP
# ADJ
# NOUN
# PUNCT
# SPACE
# PROPN
# PROPN
# NOUN
# AUX
# VERB
# ADP
# DET
# NOUN
# ADP
# NUM
# NOUN
# NOUN
# NOUN
# ADV
# ADV
# DET
# NOUN
# CCONJ
# NOUN
# ADP
# ADJ
# SCONJ
# NOUN
# VERB
# ADP
# ADP
# DET
# ADJ
# NOUN
# PART
# NUM
# NOUN
# NOUN
# PUNCT
# ADV
# PUNCT
# PROPN
# PART
# NOUN
# VERB
# SCONJ
# DET
# PROPN
# VERB
# DET
# ADJ
# NOUN
# ADV
# PUNCT
# SPACE
# NOUN
# PUNCT
# X

# %%
for token in doc:
    if token.pos_=="NOUN":
        print(token)
# Out:
# Inflation
# climb
# consumers
# brink
# expansion
# consumer
# price
# index
# measure
# prices
# goods
# services
# %
# year
# estimate
# %
# gain
# ease
# peak
# level
# summer
# food
# energy
# prices
# core
# %
# expectations
# %
# gain
# hopes
# inflation
# month
# month
# gains
# expectations
# %
# headline
# %
# estimate
# %
# increase
# core
# outlook
# %
# gain
# price
# gains
# workers
# ground
# wages
# inflation
# %
# month
# increase
# %
# earnings
# year
# earnings
# %
# earnings
# %
# Inflation
# threat
# recovery
# pandemic
# economy
# stage
# year
# growth
# level
# prices
# pump
# grocery
# stores
# problem
# inflation
# areas
# housing
# auto
# sales
# host
# areas
# officials
# problem
# interest
# rate
# hikes
# year
# pledges
# inflation
# bank
# %
# goal
# data
# job
# Credits
